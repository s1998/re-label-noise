# %%
import tensorflow as tf

# %%
sess = tf.Session()

# %%
import os

# %%
def best_model_loder():
    path = "./../saved/models/"
    all_files = os.listdir(path)
    best = [0, ""]
    for file in all_files:
        def checker(f):
            return ("meta" in file) and ("pcnn" in file) and ("att" in file) and ("wiki" in file)
        if checker(file):
            print(file)
            acc = int(file.split(".")[1])
            print(acc)
            if acc > best[0]:
                best = [acc, file]

    print("Found model with acc : {} {}".format(best[0], best[1]))
    return path + best[1][:-5]

# %%
os.listdir("./../saved/models/")
# Out:
# ['pcnn_att_wiki_520_0.1308.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_250_0.1550.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_450_0.1157.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_250_0.1255.ckpt.meta',
#  'pcnn_att_wiki_503_0.1154.ckpt.index',
#  'pcnn_att_wiki_300_0.1485.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_520_0.1281.ckpt.index',
#  'pcnn_att_wiki_200_0.1079.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_100_0.1396.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_350_0.1177.ckpt.index',
#  'pcnn_att_wiki_100_0.1278.ckpt.meta',
#  'pcnn_att_wiki_400_0.1212.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_503_0.1261.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_520_0.1052.ckpt.index',
#  'pcnn_att_wiki_50_0.1294.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_100_0.1728.ckpt.meta',
#  'pcnn_att_wiki_400_0.1212.ckpt.index',
#  'pcnn_att_wiki_503_0.1117.ckpt.index',
#  'pcnn_att_wiki_350_0.1177.ckpt.data-00000-of-00001',
#  'pcnn_att_wiki_450_0.1134.ckpt.meta',
# ...

# %%
best_model_loder()
# Out:
# pcnn_att_wiki_250_0.1255.ckpt.meta
# 1255
# pcnn_att_wiki_100_0.1278.ckpt.meta
# 1278
# pcnn_att_wiki_100_0.1728.ckpt.meta
# 1728
# pcnn_att_wiki_450_0.1134.ckpt.meta
# 1134
# pcnn_att_wiki_250_0.1550.ckpt.meta
# 1550
# pcnn_att_wiki_503_0.1093.ckpt.meta
# 1093
# pcnn_att_wiki_300_0.1485.ckpt.meta
# 1485
# pcnn_att_wiki_100_0.1146.ckpt.meta
# 1146
# pcnn_att_wiki_400_0.1292.ckpt.meta
# 1292
# pcnn_att_wiki_450_0.1264.ckpt.meta
# 1264
# pcnn_att_wiki_503_0.1446.ckpt.meta
# 1446
# pcnn_att_wiki_520_0.1058.ckpt.meta
# 1058
# pcnn_att_wiki_150_0.1431.ckpt.meta
# 1431
# pcnn_att_wiki_50_0.1718.ckpt.meta
# 1718
# pcnn_att_wiki_250_0.1284.ckpt.meta
# 1284
# pcnn_att_wiki_100_0.1396.ckpt.meta
# 1396
# pcnn_att_wiki_400_0.1251.ckpt.meta
# 1251
# pcnn_att_wiki_100_0.1495.ckpt.meta
# 1495
# pcnn_att_wiki_503_0.1032.ckpt.meta
# 1032
# pcnn_att_wiki_503_0.1065.ckpt.meta
# 1065
# pcnn_att_wiki_520_0.1052.ckpt.meta
# 1052
# pcnn_att_wiki_400_0.1193.ckpt.meta
# 1193
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = [1] * 25 + [2] * 15 + [7] * 10
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
